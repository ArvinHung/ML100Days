# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df_train = pd.read_csv("C:\\Users\\user\\Desktop\\Python learning\\02 Python 資料科學程式馬拉松\\Day 36_探索性資料分析 (EDA) 數據理解與重覆和遺失值處理\\鐵達尼號 train.csv")

# %%
# Q1：觀察票價是否有異常值的現象？

print(df_train["Fare"].mean())   # Fare = 票價
print(df_train["Fare"].std(ddof=1))

# 把資料畫出來看看
g = sns.FacetGrid(df_train, col = "Survived")
g.map(sns.displot, "Fare", kde = False)
# Out:
# 32.2042079685746
# 49.693428597180905
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
# 從上面的圖型可以看到，票價的分布不是常態分佈，
# 所以不應該用 3倍標準差或盒鬚圖的檢驗方法

# %%
# Q2：你覺得找出的異常需要做處理嗎？ (可以試著講出自己的想法)

# 從上面的圖型可以看到，票價的分布不是常態分佈，
# 所以不應該用 3倍標準差或盒鬚圖的檢驗方法
